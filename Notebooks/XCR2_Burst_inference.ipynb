# %%
cd /staging/leuven/stg_00041/Adrian/TALON_JANISZEWSKI_XCR2/
# Out:
# /ddn1/vol1/staging/leuven/stg_00041/Adrian/AJ_0065.9-sc_allele_specific/TxBURSTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import glob
from scipy.stats import ranksums

# %%
# Run txburstML

for filepath in glob.iglob(r'allele_specific/txburst/*rpkm_corr.csv'):
    print(r"%run 'txburstML.py' --njobs 10 {}".format(filepath))

# %%
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_5_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_0_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_2_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_2_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_12_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_10_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_5_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_8_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_4_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_1_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_0_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_0_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_4_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_3_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_10_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_1_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/clust_3_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_0_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/iPSC_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/iPSC_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_9_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_9_Cast_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_8_129_rpkm_corr.csv
# %run 'txburstML.py' --njobs 10 allele_specific/txburst/Day_12_Cast_rpkm_corr.csv

# %%
#! mkdir allele_specific/txburst/txburstML
#! mv allele_specific/txburst/*.pkl allele_specific/txburst/txburstML

# %%
# Run txburstPL.py for all inputs and alleles

timepoints = ['Day_0','Day_8','Day_9','Day_10','Day_12','iPSC']
clusters = ['clust_0','clust_1','clust_2','clust_3','clust_4','clust_5']
alleles = ['129_rpkm_corr', 'Cast_rpkm_corr']

for timepoint in timepoints:
    for allele in alleles:
        print(r"%run 'txburstPL.py' --file allele_specific/txburst/{}_{}.csv --njobs 15 --MLFile allele_specific/txburst/txburstML/{}_{}_ML.pkl".format(timepoint, allele, timepoint, allele))

for cluster in clusters:
    for allele in alleles:
        print(r"%run 'txburstPL.py' --file allele_specific/txburst/{}_{}.csv --njobs 15 --MLFile allele_specific/txburst/txburstML/{}_{}_ML.pkl".format(cluster, allele, cluster, allele))

# %%
# # %run 'txburstPL.py' --file data/Day_0_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_0_129_rpkm_corr_ML.pkl
# # %run 'txburstPL.py' --file data/Day_0_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_0_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_8_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_8_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_8_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_8_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_9_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_9_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_9_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_9_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_10_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_10_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_10_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_10_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_12_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_12_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/Day_12_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/Day_12_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/iPSC_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/iPSC_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/iPSC_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/iPSC_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_0_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_0_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_0_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_0_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_1_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_1_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_1_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_1_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_2_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_2_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_2_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_2_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_3_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_3_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_3_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_3_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_4_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_4_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_4_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_4_Cast_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_5_129_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_5_129_rpkm_corr_ML.pkl
# %run 'txburstPL.py' --file data/clust_5_Cast_rpkm_corr.csv --njobs 15 --MLFile data/txburstML/clust_5_Cast_rpkm_corr_ML.pkl

# %%
# Load inputs

pkl = {}

for name in glob.iglob(r'allele_specific/txburst/txburstML/*.pkl'):
    pkl[name.replace(r"allele_specific/txburst/txburstML/","")] = pd.read_pickle(name)

# %%
def pickle2df(pickle):
    
    pickle = pickle[0][pickle[1]]

    bf = pd.Series([p[0] for p in pickle], index=pickle.index)
    bs = pd.Series([p[2]/p[1] for p in pickle], index=pickle.index)
    me = pd.Series([p[2]*(p[0]/(p[0]+p[1])) for p in pickle], index=pickle.index)

    df = pd.DataFrame([bf,bs,me], index=['bf','bs','me']).T
    
    return df

# %%
for key, value in pkl.items(): 
    pkl[key] = pickle2df(value)

# %%
allelic_anno = pd.read_csv("allele_specific/txburst/GRCm38_91_Non_overlaped.bed", sep = "\t", names=["chr","start","end","GENE"])

# %%
chrom_conditions = [(-allelic_anno['chr'].isin(['MT','X','Y'])),
                   (allelic_anno['chr'] == 'X'),
                   (allelic_anno['chr'] == 'MT'),
                   (allelic_anno['chr'] == 'Y')]
outcome = ['autosomes','X_linked','mitochondrial','Y_linked']

# %%
allelic_anno['chrom_group'] = np.select(chrom_conditions, outcome)

# %%
allelic_anno
# Out:
#       chr     start       end           GENE chrom_group
# 0       1   3073253   3074322  4933401J01Rik   autosomes
# 1       1   3205901   3671498           Xkr4   autosomes
# 2       1   3999557   4409241            Rp1   autosomes
# 3       1   4490931   4497354          Sox17   autosomes
# 4       1   4773206   4785739        MTrpl15   autosomes
# ...    ..       ...       ...            ...         ...
# 30304   Y  61102247  61134259  1700040F15Rik    Y_linked
# 30305   Y  67045743  67048072          Ssty2    Y_linked
# 30306   Y  70367444  70370583  4932431L22Rik    Y_linked
# 30307   Y  90753057  90763485      MTid1-ps1    Y_linked
# 30308   Y  90784738  90816464          Erdr1    Y_linked
#
# [30309 rows x 5 columns]

# %%
for key, value in pkl.items():
    pkl[key] = value.merge(allelic_anno, on="GENE", how="left")

# %%
for key, value in pkl.items():
    pkl[key] = value[value.chrom_group.isin(['autosomes','X_linked'])]

# %%
def bf_bs_dotplot(df, title):
    
    plt.scatter(np.log10(df['bs']),np.log10(df['bf']),c=df['me'],norm=mpl.colors.LogNorm(), cmap=plt.get_cmap('viridis_r', 10))
    plt.colorbar()
    plt.xlabel("Burst size")
    plt.ylabel("Burst frequency")
    plt.title(title)

    axes = plt.gca()
    axes.set_xlim([-0.1,4])
    axes.set_ylim([-3,1])

    plt.show()

# %%
for key, value in pkl.items():
    bf_bs_dotplot(value, key)

# %%
def bf_hist(df, title):
    plt.hist(np.log10(df.bf), bins=100)
    plt.xlabel(r'Burst frequency (log$_{10}$)')
    plt.show()

# %%
def bf_density(df, title, export = False):  
    import seaborn as sns
    # Done much easier using displot in new seaborn 0.11
    
    auto = df[df["chrom_group"] == 'autosomes']
    X = df[df["chrom_group"] == 'X_linked']
    
    fig = plt.figure(figsize = (5,1.5))
    
    sns.distplot(np.log2(auto.bf), hist=False, color='lightslategrey')
    plt.axvline(np.median(np.log2(auto.bf)),color='lightslategrey', linestyle='--')

    sns.distplot(np.log2(X.bf), hist=False, color ='salmon')
    plt.axvline(np.median(np.log2(X.bf)),color='salmon', linestyle='--')
    
    #fig.legend(labels=['autosomes','X_linked'])
    plt.title(title)
    
    #plt.rcParams['pdf.use14corefonts'] = True
    plt.rcParams['ps.fonttype'] = 42
    
    if export:
        plt.savefig("allele_specific/txburst/BF " + title + ".pdf", format = "pdf")

# %%
def bs_density(df, title, export = True):  
    import seaborn as sns
    # Done much easier using displot in new seaborn 0.11
    auto = df[df["chrom_group"] == 'autosomes']
    X = df[df["chrom_group"] == 'X_linked']
    
    fig = plt.figure(figsize = (5,1.5))
    
    sns.distplot(np.log10(auto.bs), hist=False, color='lightslategrey')
    plt.axvline(np.median(np.log10(auto.bs)),color='lightslategrey', linestyle='--')

    sns.distplot(np.log10(X.bs), hist=False, color ='darkorange')
    plt.axvline(np.median(np.log10(X.bs)),color='darkorange', linestyle='--')
    
    plt.rcParams['ps.fonttype'] = 42
    #fig.legend(labels=['autosomes','X_linked'])
    plt.title(title)
    
    if export:
        plt.savefig("allele_specific/txburst/BS " + title + ".pdf", format = "pdf")

# %%
def bf_bs_median(df, title):
    # want median of bf and bs for autosomes and X-linked
    auto = df[df["chrom_group"] == 'autosomes']
    X = df[df["chrom_group"] == 'X_linked']
    
    auto_bf_bs = [np.median(np.log2(auto.bf)), np.median(np.log2(auto.bs))]
    X_bf_bs = [np.median(np.log2(X.bf)), np.median(np.log2(X.bs))]
    
    medians = pd.DataFrame(list(zip(auto_bf_bs, X_bf_bs)),  columns = ["Autosomes","X_linked"], index =["bf","bs"])
    
    medians.columns = pd.MultiIndex.from_product([[title],medians.columns])
    display(medians)

# %%
for key, value in pkl.items():
    bf_bs_median(value, key)
# Out:
#    clust_4_Cast_rpkm_corr_ML.pkl
#                        Autosomes  X_linked
# bf                     -3.179888 -3.192013
# bs                      4.686272  4.767918
#    clust_4_129_rpkm_corr_ML.pkl
#                       Autosomes  X_linked
# bf                    -3.389147 -3.187226
# bs                     4.407979  4.437068
#    Day_10_129_rpkm_corr_ML.pkl
#                      Autosomes  X_linked
# bf                   -3.659820 -6.331618
# bs                    4.541398  4.052115
#    Day_12_Cast_rpkm_corr_ML.pkl
#                       Autosomes  X_linked
# bf                    -3.768297 -3.799581
# bs                     4.750684  4.258115
#    clust_2_129_rpkm_corr_ML.pkl
#                       Autosomes  X_linked
# bf                    -3.466692 -6.466529
# bs                     4.230112  3.699526
#    clust_5_129_rpkm_corr_ML.pkl
#                       Autosomes  X_linked
# bf                    -3.557970 -2.974616
# bs                     3.849206  4.007731
# ...

# %%
for key, value in pkl.items():
    bf_density(value, key, export = False)
# Out:
# /data/leuven/320/vsc32023/miniconda/envs/allele_specific/lib/python3.7/site-packages/ipykernel_launcher.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
for key, value in pkl.items():
    bs_density(value, key, export = True)
# Out:
# /data/leuven/320/vsc32023/miniconda/envs/allele_specific/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   import sys

# %%
def bf_bs_ranksums(df, title):
    # Test whether theres sign diff between x and auto on bf and bs
    
    auto = df[df["chrom_group"] == 'autosomes']
    X = df[df["chrom_group"] == 'X_linked']
    
    auto_bf = np.array(np.log2(auto.bf))
    X_bf = np.array(np.log2(X.bf))
    
    bf_result = ranksums(auto_bf, X_bf)
    
    auto_bs = np.array(np.log2(auto.bs))
    X_bs = np.array(np.log2(X.bs))
    
    bs_result = ranksums(auto_bs, X_bs)
    
    results = pd.DataFrame(list(zip(bf_result, bs_result)), columns=["bf","bs"], index =["statistic","pval"])
    
    results.columns = pd.MultiIndex.from_product([[title],results.columns])
    return results

# %%
wilcoxon_results = []
for key, value in pkl.items():
    results = bf_bs_ranksums(value, key)
    wilcoxon_results.append(results)

# %%
wilcoxon_results
# Out:
# [          clust_4_Cast_rpkm_corr_ML.pkl
#                                       bf        bs
#  statistic                     -0.641118  0.007561
#  pval                           0.521446  0.993967,
#            clust_4_129_rpkm_corr_ML.pkl
#                                      bf        bs
#  statistic                    -0.695876  0.558906
#  pval                          0.486506  0.576226,
#            Day_10_129_rpkm_corr_ML.pkl
#                                     bf        bs
#  statistic                1.068615e+01  1.297337
#  pval                     1.181752e-26  0.194515,
#            Day_12_Cast_rpkm_corr_ML.pkl
#                                      bf        bs
#  statistic                    -0.146141  2.193300
#  pval                          0.883810  0.028286,
#            clust_2_129_rpkm_corr_ML.pkl
#                                      bf        bs
#  statistic                 8.166284e+00  0.756956
#  pval                      3.180352e-16  0.449076,
# ...

# %%
from functools import reduce
wilcoxon_results_df = reduce(lambda x, y: pd.merge(x, y, left_index=True, right_index=True), wilcoxon_results)

# %%
wilcoxon_results_df
# Out:
#           clust_4_Cast_rpkm_corr_ML.pkl            \
#                                      bf        bs
# statistic                     -0.641118  0.007561
# pval                           0.521446  0.993967
#
#           clust_4_129_rpkm_corr_ML.pkl           Day_10_129_rpkm_corr_ML.pkl  \
#                                     bf        bs                          bf
# statistic                    -0.695876  0.558906                1.068615e+01
# pval                          0.486506  0.576226                1.181752e-26
#
#                     Day_12_Cast_rpkm_corr_ML.pkl            \
#                  bs                           bf        bs
# statistic  1.297337                    -0.146141  2.193300
# pval       0.194515                     0.883810  0.028286
#
#           clust_2_129_rpkm_corr_ML.pkl            ...  \
#                                     bf        bs  ...
# statistic                 8.166284e+00  0.756956  ...
# ...
